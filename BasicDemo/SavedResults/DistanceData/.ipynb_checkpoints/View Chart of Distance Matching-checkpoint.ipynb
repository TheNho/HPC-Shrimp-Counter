# %%
save_list = []
for i in range(1, 15):
    filename = f"SaveDistance{i}.txt"
    file1 = open(filename, 'r')
    read_list = file1.readlines()
    save_list += read_list

# %%
number_list = []
for number in save_list:
    number_list.append(float(number))

# %%
len(number_list), number_list[0]
# Out:
# (492682, 16.139925)

# %%
import numpy as np
number_array = np.array(number_list)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,5))
plt.xlabel("Point")
plt.ylabel("Distance(Pixel)")
y = np.arange(len(number_array))
plt.grid()
plt.scatter(y, number_array, alpha=0.5, marker='o', s=2)
plt.show()

# %%
np.sum(number_array>20)
# Out:
# 1221

# %%
len(number_array)
# Out:
# 492682

# %%
np.mean(number_array)
# Out:
# 2.0282808294559165

# %%
np.std(number_array)
# Out:
# 3.538705543644187
